# %%
# %matplotlib inline
import pylab as plt
from astropy.io import fits
import source_extracting
import diff_image
from IPython.display import Image

# %%
file = "../VVDS22H_MOS05-05_NUV.fits"
hdulist = fits.open(file)
framecube = hdulist[0].data
pngout = "../VVDS22H_MOS05-05_NUV_detsources"

# %%
image, bad_frame_mask = diff_image.diff_image(file)
print image.shape
print bad_frame_mask.shape
# Out:
# (119, 119)
# (43,)

# %%
unique_extracted_objects = source_extracting.find_all_objects(framecube, bad_frame_mask, pngout)
print len(unique_extracted_objects)
# Out:
# 324

# %%
plt.imshow(framecube[2,:,:])

# %%
Image(filename=pngout)
